# %% [markdown]
# <a href="https://colab.research.google.com/github/DaramG-star/Backend/blob/main/0328_Django.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## READ
#
# 1. 전체 게시글 조회
#
# 2. 단일 게시글 조회
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Create
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## HTTP
# 네트워크 상에서 데이터(리소스)를 주고 받기위한 약속
#
# ## HTTP request methods
# - 데이터에 대해 수행을 원하는 작업을 나타내는 것
#     - 서버에게 원하는 작업의 종류를 알려주는 역할
# - 클라이언트가 웹서버애 특정 동작을 요청하기 위해 사용하는 표준 명령어
# - 대표 메서드
#     - GET, POST
#
# ## 'GET' method
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 'POST' Method
#
# 서버에 데이터를 제출하여 리소스를 변경(생성, 수정, 삭제) 하는 데 사용
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## HTTP resopnce status code
#
# 서버가 클라이언트의 요청에 대한 처리 결과를 나타내는 3자리 숫자
#
# - 클라이언트에게 요청 처리 결과를 명확히 전달
#
# - 문제 발생 시 디버깅에 도움
#
# - 웹 애플리케이션의 동작을 제어하는 데 사용
#
# ## 403 Forbidden
#
# 서버에 요청이 전달되었지만, 권한 때문에 거절되었다는 것을 의미
#
# ### CSRF
# '사이트 간 요청 위조'
#
# 사용자가 자신의 의지와 무관하게 공격자가 의도한 행동을 하여 특정 웹 페이지를 보안에 취약하게 하거나 수정, 삭제 등의 작업을 하게 만드는 공격 방법
#
# ![스크린샷 2025-03-28 103705.png](data:image/png;base64,...)![스크린샷 2025-03-28 103726.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## redirect()
#
# 클라이언트가 인자에 작성된 주소로 다시 요청을 보내도록 하는 함수
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Delete()
#
# 삭제는 POST로 요청해야함
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
