# %% [markdown]
# <a href="https://colab.research.google.com/github/DaramG-star/Backend/blob/main/0408_Database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SQLite 데이터 타입
#
# 1. NULL
# - 아무런 값도 포함하지 않음을 나타냄
#
# 2. INTEGER
# - 정수
#
# 3. REAL
# - 부동 소수점
#
# 4. TEXT
# - 문자열
#
# 5. BLOB
# - 이미지, 동영상, 문서 등의 바이너리 데이터
#
# ## 제약 조건
#
# 1. PRIMARY KEY
# - 해당 필드를 기본 키로 지정. INTEGER 타입에만 적용되며, INT, BIGINT 등과 같은 다른 정수 유형은 적용되지 않음.
#
# 2. NOT NULL
# - 해당 필드에 NULL값을 허용하지 않도록 지정
#
# 3. FOREIGN KEY
# - 다른 테이블과의 외래 키 관계를 정의
#
# ## AUTOINCREMENT keyword
# 자동으로 고유한 정수 값을 생성하고 할당하는 필드 속성
#
# - 필드의 자동 증가를 나타내는 특수한 키워드
#
# - 주로 primary key 필드에 적용
#
# - INTEGER PRIMARY KEY AUTOINCREMENT가 작성된 필드는 항상 새로운 레코드에 대해 이전 최대 값보다 큰 값을 할당
#
# - 삭제된 값은 무시되며 재사용할 수 없게 됨

# %% [markdown]
# ## ALTER TABLE statement
# 테이블 및 필드 조작
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ## Country 필드 추가
#
# ```
# ALTER TABLE
#     examples
# ADD COLUMN
#     Country VARCHAR(100) NOT NULL DEFAULT 'default value'
# ```

# %% [markdown]
# ### Examples 테이블에 Age, Address 필드 추가
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ALTER TABLE RENAME COLUMN
#
# ![image.png](data:image/png;base64,...)
#
# ### examples 테이블 Address 필드의 이름을 PostCode로 변경
# ```
# ALTER TABLE examples
# RENAME COLUMN Address TO PostCode;
# ```

# %% [markdown]
# ## ALTER TABLE DROP COLUMN
# 테이블의 필드를 삭제
#
# ```
# ALTER TABLE table_name
# DROP COLUMN column_name
# ```
#
# ## ALTER TABLE RENAME TO
# ```
# ALTER TABLE table_name
# RENAME TO new_table_name;
# ```

# %% [markdown]
# ## DROP TABLE statement
# 테이블 삭제
#
# ```
# DROP TABLE table_name;
# ```

# %% [markdown]
# ## INSERT statement
# 테이블 레코드 삽입
#
# ```
# INSERT INTO table_name(c1, c2, ...)
# VALUES (v1, v2, ...);
# ```
# INSERT INTO 절 다음에 테입르 이름과 괄호 안에 필드 목록 작성
#
# VALUES 키워드 다음 괄호 안에 해당 필드에 삽입할 값 목록 작성
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## UPDATE statement
# 테이블 레코드 수정
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DELETE statement
# 테이블 레코드 삭제
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 관계
# 여러 테이블 간의 논리적 연결
#
# ![image.png](data:image/png;base64,...)
#
# ## JOIN
# 테이블 분리 시 데이터 관리는 용이해지나, 출력 시에는 문제가 있음.
#
# 테이블 한 개만을 출력할 수 밖에 없어 다른 테이블과 결합하여 출력하는 것이 필요

# %% [markdown]
# ## JOIN clause
# 둘 이상의 테이블에서 데이터를 검색하는 방법
#
# 1. INNER JOIN
# 2. LEFT JOIN
#
# ## INNER JOIN clause
# 두 테이블에서 값이 일치하는 레코드에 대해서만 결과를 반환
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## LEFT JOIN clause
#
# 오른쪽 테이블의 일치하는 레코드와 함께 왼쪽 테이블의 모든 레코드 반환
#
# ![image.png](data:image/png;base64,...)
