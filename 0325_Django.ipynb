# %% [markdown]
# <a href="https://colab.research.google.com/github/DaramG-star/Backend/blob/main/0325_Django.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Django Template Language(DTL)
# 템플릿에서 조건, 반복, 변수 등의 프로그래밍적 기능을 제공하는 시스템
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [URL 설정]
# ![image.png](data:image/png;base64,...)
#
# [view 설정]
# ![image.png](data:image/png;base64,...)
#
# [html 설정]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 데이터를 가져오기
#
# HTML 'form'은 HTTP 요청을 서버에 보내는 가장 편리한 방법
#
# adtion, method = form의 핵심 속성 2가지
#
# ![image.png](data:image/png;base64,...)
#
# Get 방식은 검색에 쓰이고, Post 방식은 데이터를 삭제, 수정, 생성, 조작에 쓰임

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 데이터를 제출햇을 때 서버는 name 속성에 설정된 값을 통해서만 사용자가 입력한 데이터에 접근할 수 있음

# %% [markdown]
# ## Query String Parameters
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2번째 앱 pages 생성 후 발생할 수 있는 문제
# view 함수 이름이 같거나 같은 패턴의 url 주소 가
